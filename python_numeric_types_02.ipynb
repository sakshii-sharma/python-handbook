# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshii-sharma/python-handbook/blob/main/python_numeric_types_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### `Problem 1`: Write a program that will give you in hand monthly salary after deduction on CTC - HRA(10%), DA(5%), PF(3%) and taxes deduction as below:
#
# > Salary(Lakhs) : Tax(%)
#
# *   Below 5 : 0%
# *   5-10 : 10%
# *   10-20 : 20%
# *   aboove 20 : 30%

# %%
# Write code here
salary = int(input('Enter salary : '))
tax = 0
final = 0

if salary > 500000 and salary < 10000000 :
  tax   = 0.1 * salary
  final = salary - tax

elif salary >= 1000000 and salary < 20000000 :
  tax   = 0.2 * salary
  final = salary - tax

else :
  tax   = 0.2 * salary
  final = salary - tax

print(salary)
# Out:
# Enter salary : 5000
# 5000

# %% [markdown]
# ### `Problem 2`: Write a program that take a user input of three angles and will find out whether it can form a triangle or not.

# %%
# Write code here
first_angle = int(input('enter first angle : '))
second_angle = int(input('enter second angle : '))
third_angle = int(input('enter third angle : '))

if first_angle + second_angle + third_angle == 180:
  print('triangle formed')
else:
  print('cannot be formed')
# Out:
# enter first angle : 80
# enter second angle : 50
# enter third angle : 50
# triangle formed

# %% [markdown]
# ### `Problem 3`: Write a program that will take user input of cost price and selling price and determines whether its a loss or a profit.

# %%
# Write code here
sp = int(input('Enter SP '))
cp = int(input('Enter CP '))

if sp > cp:
  print('Profit ', sp-cp)
elif cp > sp:
  print('Loss ', cp-sp)
else:
  print('no profit no loss')

# %% [markdown]
# ### `Problem 4`: Write a menu-driven program -
# 1. cm to ft
# 2. km to miles
# 3. USD to INR
# 4. exit

# %%
# Write code here
menu = int(input('enter 1 for cm , 2 for km , 3 for usd '))

if menu==1:
  x = int(input('enter cm '))
  x = x/30.48
  print('feet ', x)

elif menu==2:
  x = int(input('enter km '))
  x = x * 0.621371
  print('km  ', x)

else:
  x = int(input('enter usd '))
  x = x * 95.04
  print('inr  ', x)

# %% [markdown]
# ### `Problem 5` - Exercise 12: Display Fibonacci series up to 10 terms.
#
# *Note: The Fibonacci Sequence is a series of numbers. The next number is found by adding up the two numbers before it. The first two numbers are 0 and 1. For example, 0, 1, 1, 2, 3, 5, 8, 13, 21. The next number in this series above is 13+21 = 34*

# %%
# write code here

a = 0
b = 1
n = int(input('Enter n '))

if n>2:
  print(a, b, '', end='')
  n = n - 2
  while n>0:
    sum = a + b
    a = b
    b = sum
    print(sum, '', end='')
    n = n - 1
elif n==2:
  print(a, b)
else:
  print(a)

# %% [markdown]
# ### `Problem 6` - Find the factorial of a given number.
#
# Write a program to use the loop to find the factorial of a given number.
#
# The factorial (symbol: `!`) means to multiply all whole numbers from the chosen number down to 1.
#
# For example: calculate the factorial of 5
#
# ```bash
# 5! = 5 × 4 × 3 × 2 × 1 = 120
# ```
#
# Output:
#
# ```bash
# 120
# ```

# %%
# Write code here

n = int(input('find factorial of '))
fact = 1

while n>0:
  fact = fact * n
  n = n - 1

print('Factorial : ', fact)

# %% [markdown]
# ### `Problem 7` - Reverse a given integer number.
#
# Example:
#
# `Input:`
#
# ```bash
# 76542
# ```
#
# `Output:`
#
# ```bash
# 24567
# ```

# %%
# Write code here

n = int(input('enter n'))
num = str(n)
rev = num[::-1]
print('Reverse ', rev)

# %% [markdown]
# ### `Problem 8`: Take a user input as integer N. Find out the sum from 1 to N. If any number if divisible by 5, then skip that number. And if the sum is greater than 300, don't need to calculate the sum further more. Print the final result. And don't use for loop to solve this problem.
#
# **Example 1:**
#
# `Input:`
#
# ```bash
# 30
# ```
#
# `Output:`
#
# ```bash
# 276
# ```

# %%
# Write code here

def find_sum(current, n, total):
    if current > n:
        return total

    if current % 5 == 0:
        return find_sum(current + 1, n, total)

    # Stop before the sum exceeds 300
    if total + current > 300:
        return total

    return find_sum(current + 1, n, total + current)


N = int(input("Enter N: "))
print(find_sum(1, N, 0))

# Hint was Recursion !
# Out:
# Enter N: 30
# 276

# %% [markdown]
# ### `Problem 9`: Write a program that keeps on accepting a number from the user until the user enters Zero. Display the sum and average of all the numbers.

# %%
# Write code here
n = int(input('Enter n '))
sum = 0
avg = 0
cnt = 1
while n!=0:
  sum = sum + n
  avg = sum / cnt
  cnt = cnt + 1
  n = int(input('Enter n '))
print('Sum  ', sum)
print('Avg  ', avg)
# Out:
# Enter n 7
# Enter n 5
# Enter n 0
# Sum   12
# Avg   6.0

# %% [markdown]
# ###`Problem 9`: Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
# Write code here
sum = 0
for i in range(2000,3201):
  if i%7==0 and i%5!=0:
    sum = sum + i
  if i !=3200:
   print(sum, ' , ', end='')
  else:
    print(sum, ' ', end='')
# Out:
# 0  , 0  , 2002  , 2002  , 2002  , 2002  , 2002  , 2002  , 2002  , 4011  , 4011  , 4011  , 4011  , 4011  , 4011  , 4011  , 6027  , 6027  , 6027  , 6027  , 6027  , 6027  , 6027  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 8050  , 10087  , 10087  , 10087  , 10087  , 10087  , 10087  , 10087  , 12131  , 12131  , 12131  , 12131  , 12131  , 12131  , 12131  , 14182  , 14182  , 14182  , 14182  , 14182  , 14182  , 14182  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 16240  , 18312  , 18312  , 18312  , 18312  , 18312  , 18312  , 18312  , 20391  , 20391  , 20391  , 20391  , 20391  , 20391  , 20391  , 22477  , 22477  , 22477  , 22477  , 22477  , 22477  , 22477  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 24570  , 26677  , 26677  , 26677  , 26677  , 26677  , 26677  , 26677  , 28791  , 28791 
# ...

# %% [markdown]
# ###`Problem 10`: Write a program, which will find all such numbers between 1000 and 3000 (both included) such that each digit of the number is an even number. The numbers obtained should be printed in a space-separated sequence on a single line.

# %%
# Write code here

sum = 0
for i in range(1000,3001):
  if i%2==0:
    if i !=3001:
      print(i, '  ', end='')
    else:
      print(i, '', end='')
# Out:
# 1000   1002   1004   1006   1008   1010   1012   1014   1016   1018   1020   1022   1024   1026   1028   1030   1032   1034   1036   1038   1040   1042   1044   1046   1048   1050   1052   1054   1056   1058   1060   1062   1064   1066   1068   1070   1072   1074   1076   1078   1080   1082   1084   1086   1088   1090   1092   1094   1096   1098   1100   1102   1104   1106   1108   1110   1112   1114   1116   1118   1120   1122   1124   1126   1128   1130   1132   1134   1136   1138   1140   1142   1144   1146   1148   1150   1152   1154   1156   1158   1160   1162   1164   1166   1168   1170   1172   1174   1176   1178   1180   1182   1184   1186   1188   1190   1192   1194   1196   1198   1200   1202   1204   1206   1208   1210   1212   1214   1216   1218   1220   1222   1224   1226   1228   1230   1232   1234   1236   1238   1240   1242   1244   1246   1248   1250   1252   1254   1256   1258   1260   1262   1264   1266   1268   1270   1272   1274   1276   1278   1280   1282   1284
# ...

# %% [markdown]
# ###`Problem 11`: A robot moves in a plane starting from the original point (0,0). The robot can move toward UP, DOWN, LEFT and RIGHT with a given steps.
# The trace of robot movement is shown as the following:
# ```
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# !
# ```
# > The numbers after the direction are steps.
#
# > `!` means robot stop there.
#
# **Please write a program to compute the distance from current position after a sequence of movement and original point.**
#
# *If the distance is a float, then just print the nearest integer.*
#
# Example:
#
# `Input`:
# ```
# UP 5
# DOWN 3
# LEFT 3
# RIGHT 2
# !
# ```
# `Output`:
# ```
# 2
# ```

# %%
# Write code here
import math

x = 0
y = 0
i = 0
str = input('Enter Distance: ')
s = str.split(' ')

while s[i]!='!':
  if s[i]=='UP':
    i = i + 1
    x = x + int(s[i])
  elif s[i]=='DOWN':
    i = i + 1
    x = x - int(s[i])
  elif s[i]=='LEFT':
    i = i + 1
    y = y - int(s[i])
  elif s[i]=='RIGHT':
    i = i + 1
    y = y + int(s[i])
  i = i + 1

dist = math.sqrt(x*x + y*y)
print(math.floor(dist))
# Out:
# Enter Distance: UP 5 DOWN 3 LEFT 3 RIGHT 2 !
# 2

# %% [markdown]
# ###`Problem 12`:Write a program to print whether a given number is a prime number or not

# %%
# Write code here

n = int(input('enter n'))

flag = 1

for i in range(2,n):
  if flag==0 :
    break

  if n%i==0 or n==2:
    flag = 0
    break

if flag==0:
  print('not prime')
else:
  print('prime')
# Out:
# enter n5
# prime

# %% [markdown]
# ###`Problem 13`:Print all the Armstrong numbers in a given range.
# Range will be provided by the user<br>
# Armstrong number is a number that is equal to the sum of cubes of its digits. For example 0, 1, 153, 370, 371 and 407 are the Armstrong numbers.

# %%
# Write code here
n = int(input('enter n'))
sum = 0
temp = n

while temp>0 :
  d = temp % 10
  sum = sum + (d**3)
  temp = temp // 10

if sum == n:
  print('armstrong')
else:
  print('not armstrong')
# Out:
# enter n153
# armstrong

# %% [markdown]
# ###`Problem 14`:Calculate the angle between the hour hand and minute hand.
#
# Note: There can be two angles between hands; we need to print a minimum of two. Also, we need to print the floor of the final result angle. For example, if the final angle is 10.61, we need to print 10.
#
# Input:<br>
# H = 9 , M = 0<br>
# Output:<br>
# 90<br>
# Explanation:<br>
# The minimum angle between hour and minute
# hand when the time is 9 is 90 degress.

# %%
# Write code here
H = int(input('Input H '))
M = int(input('Input M '))

degH = H * 30
degM = M * 6
diff = 0

if degH > degM:
  diff = degH - degM
else:
  diff = degM - degH

if diff > 360-diff:
  print(360-diff)
else:
  print(diff)

# %%
360/12 # Each Hour Hand
360/60 # Each Minute Hand

# %% [markdown]
# ###`Problem 15`:Given two rectangles, find if the given two rectangles overlap or not. A rectangle is denoted by providing the x and y coordinates of two points: the left top corner and the right bottom corner of the rectangle. Two rectangles sharing a side are considered overlapping. (L1 and R1 are the extreme points of the first rectangle and L2 and R2 are the extreme points of the second rectangle).
#
# Note: It may be assumed that the rectangles are parallel to the coordinate axis.
#
# <img src='https://www.geeksforgeeks.org/wp-content/uploads/rectanglesOverlap.png' width='300' height='200'>

# %%
# Write code here

l1 = (0,10)
r1 = (10,0)

l2 = (5,5)
r2 = (15,-5)

# Case 1 : Rectangle 1 is completely left of Rectangle 2
# Case 2 : Rectangle 1 is completely right of Rectangle 2
# Case 3 : Rectangle 1 is completely above Rectangle 2
# Case 4 : Rectangle 1 is completely below Rectangle 2

def is_overlap(l1, r1, l2, r2):

    # Rectangle 1 is left of Rectangle 2
    if r1[0] < l2[0]:
        return False

    # Rectangle 1 is right of Rectangle 2
    if l1[0] > r2[0]:
        return False

    # Rectangle 1 is above Rectangle 2
    if r1[1] > l2[1]:
        return False

    # Rectangle 1 is below Rectangle 2
    if l1[1] < r2[1]:
        return False

    return True

result = is_overlap(l1, r1, l2, r2)

if result:
    print("Rectangles Overlap")
else:
    print("Rectangles Do Not Overlap")
# Out:
# Rectangles Overlap
